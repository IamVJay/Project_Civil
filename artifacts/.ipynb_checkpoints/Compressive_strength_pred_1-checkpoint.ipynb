# %% [markdown]
# # 1.Problem statement

# %% [raw]
# Predicting Compressive Strength of Concrete

# %%
# Import Libraries 
import numpy as np
import pandas as pd

import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score,accuracy_score

# %% [markdown]
# # 2. Data gathering

# %%
df = pd.read_csv('Concrete_Data.csv')

# %%
df
# Out:
#      Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 0                           540.0                                       0.0
# 1                           540.0                                       0.0
# 2                           332.5                                     142.5
# 3                           332.5                                     142.5
# 4                           198.6                                     132.4
# ..                            ...                                       ...
# 995                         158.6                                     148.9
# 996                         152.6                                     238.7
# 997                         310.0                                     142.8
# 998                         304.8                                       0.0
# 999                         150.9                                       0.0
#
#      Fly Ash (kg in a m^3 mixture)  Water (kg in a m^3 mixture)  \
# 0                              0.0                        162.0
# 1                              0.0                        162.0
# 2                              0.0                        228.0
# 3                              0.0                        228.0
# 4                              0.0                        192.0
# ..                             ...                          ...
# 995                          116.0                        175.1
# 996                            0.0                        200.0
# 997                            0.0                        167.9
# 998                           99.6                        196.0
# 999                          183.9                        166.6
#
#      Superplasticizer (kg in a m^3 mixture)  \
# 0                                       2.5
# 1                                       2.5
# 2                                       0.0
# 3                                       0.0
# 4                                       0.0
# ..                                      ...
# 995                                    15.0
# 996                                     6.3
# 997                                    10.0
# 998                                     9.8
# 999                                    11.6
#
#      Coarse Aggregate  (kg in a m^3 mixture)  \
# 0                                     1040.0
# 1                                     1055.0
# 2                                      932.0
# 3                                      932.0
# 4                                      978.4
# ..                                       ...
# 995                                    953.3
# 996                                   1001.8
# 997                                    914.3
# 998                                    959.4
# 999                                    991.2
#
#      Fine Aggregate (kg in a m^3 mixture)  Age (day)  \
# 0                                   676.0         28
# 1                                   676.0         28
# 2                                   594.0        270
# 3                                   594.0        365
# 4                                   825.5        360
# ..                                    ...        ...
# 995                                 719.7         28
# 996                                 683.9         28
# 997                                 804.0         28
# 998                                 705.2         28
# 999                                 772.2         28
#
#      Concrete compressive strength(MPa)
# 0                                  79.99
# 1                                  61.89
# 2                                  40.27
# 3                                  41.05
# 4                                  44.30
# ..                                   ...
# 995                                27.68
# 996                                26.86
# 997                                45.30
# 998                                30.12
# 999                                15.57
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 3. EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Cement (kg in a m^3 mixture)              1000 non-null   float64
#  1   Blast Furnace Slag (kg in a m^3 mixture)  1000 non-null   float64
#  2   Fly Ash (kg in a m^3 mixture)             1000 non-null   float64
#  3   Water (kg in a m^3 mixture)               1000 non-null   float64
#  4   Superplasticizer (kg in a m^3 mixture)    1000 non-null   float64
#  5   Coarse Aggregate  (kg in a m^3 mixture)   1000 non-null   float64
#  6   Fine Aggregate (kg in a m^3 mixture)      1000 non-null   float64
#  7   Age (day)                                 1000 non-null   int64
#  8   Concrete compressive strength(MPa)        1000 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 70.4 KB

# %%
df.isna().sum()
# Out:
# Cement (kg in a m^3 mixture)                0
# Blast Furnace Slag (kg in a m^3 mixture)    0
# Fly Ash (kg in a m^3 mixture)               0
# Water (kg in a m^3 mixture)                 0
# Superplasticizer (kg in a m^3 mixture)      0
# Coarse Aggregate  (kg in a m^3 mixture)     0
# Fine Aggregate (kg in a m^3 mixture)        0
# Age (day)                                   0
# Concrete compressive strength(MPa)          0
# dtype: int64

# %% [raw]
# # Assumption
# 1. Linearity

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                           Cement (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                  1.000000
# Blast Furnace Slag (kg in a m^3 mixture)                     -0.268367
# Fly Ash (kg in a m^3 mixture)                                -0.399852
# Water (kg in a m^3 mixture)                                  -0.080754
# Superplasticizer (kg in a m^3 mixture)                        0.100427
# Coarse Aggregate  (kg in a m^3 mixture)                      -0.117377
# Fine Aggregate (kg in a m^3 mixture)                         -0.229847
# Age (day)                                                     0.080175
# Concrete compressive strength(MPa)                            0.500086
#
#                                           Blast Furnace Slag (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                             -0.268367
# Blast Furnace Slag (kg in a m^3 mixture)                                  1.000000
# Fly Ash (kg in a m^3 mixture)                                            -0.324537
# Water (kg in a m^3 mixture)                                               0.108738
# Superplasticizer (kg in a m^3 mixture)                                    0.038641
# Coarse Aggregate  (kg in a m^3 mixture)                                  -0.287605
# Fine Aggregate (kg in a m^3 mixture)                                     -0.280572
# Age (day)                                                                -0.041152
# Concrete compressive strength(MPa)                                        0.128026
#
#                                           Fly Ash (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                  -0.399852
# Blast Furnace Slag (kg in a m^3 mixture)                      -0.324537
# Fly Ash (kg in a m^3 mixture)                                  1.000000
# Water (kg in a m^3 mixture)                                   -0.272959
# Superplasticizer (kg in a m^3 mixture)                         0.378577
# Coarse Aggregate  (kg in a m^3 mixture)                        0.013752
# Fine Aggregate (kg in a m^3 mixture)                           0.082990
# Age (day)                                                     -0.153180
# Concrete compressive strength(MPa)                            -0.101424
#
#                                           Water (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                -0.080754
# Blast Furnace Slag (kg in a m^3 mixture)                     0.108738
# Fly Ash (kg in a m^3 mixture)                               -0.272959
# Water (kg in a m^3 mixture)                                  1.000000
# Superplasticizer (kg in a m^3 mixture)                      -0.668030
# Coarse Aggregate  (kg in a m^3 mixture)                     -0.171723
# Fine Aggregate (kg in a m^3 mixture)                        -0.450713
# Age (day)                                                    0.282923
# Concrete compressive strength(MPa)                          -0.295044
#
#                                           Superplasticizer (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                            0.100427
# Blast Furnace Slag (kg in a m^3 mixture)                                0.038641
# Fly Ash (kg in a m^3 mixture)                                           0.378577
# Water (kg in a m^3 mixture)                                            -0.668030
# Superplasticizer (kg in a m^3 mixture)                                  1.000000
# Coarse Aggregate  (kg in a m^3 mixture)                                -0.262132
# Fine Aggregate (kg in a m^3 mixture)                                    0.226201
# Age (day)                                                              -0.190124
# Concrete compressive strength(MPa)                                      0.370697
#
#                                           Coarse Aggregate  (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                            -0.117377
# Blast Furnace Slag (kg in a m^3 mixture)                                -0.287605
# Fly Ash (kg in a m^3 mixture)                                            0.013752
# Water (kg in a m^3 mixture)                                             -0.171723
# Superplasticizer (kg in a m^3 mixture)                                  -0.262132
# Coarse Aggregate  (kg in a m^3 mixture)                                  1.000000
# Fine Aggregate (kg in a m^3 mixture)                                    -0.184087
# Age (day)                                                               -0.012659
# Concrete compressive strength(MPa)                                      -0.159582
#
#                                           Fine Aggregate (kg in a m^3 mixture)  \
# Cement (kg in a m^3 mixture)                                         -0.229847
# Blast Furnace Slag (kg in a m^3 mixture)                             -0.280572
# Fly Ash (kg in a m^3 mixture)                                         0.082990
# Water (kg in a m^3 mixture)                                          -0.450713
# Superplasticizer (kg in a m^3 mixture)                                0.226201
# Coarse Aggregate  (kg in a m^3 mixture)                              -0.184087
# Fine Aggregate (kg in a m^3 mixture)                                  1.000000
# Age (day)                                                            -0.158490
# Concrete compressive strength(MPa)                                   -0.166763
#
#                                           Age (day)  \
# Cement (kg in a m^3 mixture)               0.080175
# Blast Furnace Slag (kg in a m^3 mixture)  -0.041152
# Fly Ash (kg in a m^3 mixture)             -0.153180
# Water (kg in a m^3 mixture)                0.282923
# Superplasticizer (kg in a m^3 mixture)    -0.190124
# Coarse Aggregate  (kg in a m^3 mixture)   -0.012659
# Fine Aggregate (kg in a m^3 mixture)      -0.158490
# Age (day)                                  1.000000
# Concrete compressive strength(MPa)         0.333786
#
#                                           Concrete compressive strength(MPa)
# Cement (kg in a m^3 mixture)                                         0.500086
# Blast Furnace Slag (kg in a m^3 mixture)                             0.128026
# Fly Ash (kg in a m^3 mixture)                                       -0.101424
# Water (kg in a m^3 mixture)                                         -0.295044
# Superplasticizer (kg in a m^3 mixture)                               0.370697
# Coarse Aggregate  (kg in a m^3 mixture)                             -0.159582
# Fine Aggregate (kg in a m^3 mixture)                                -0.166763
# Age (day)                                                            0.333786
# Concrete compressive strength(MPa)                                   1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
# No Multicolinearity
vif_list = []
for i in range(df.shape[1]-1):
    vif = variance_inflation_factor(df.to_numpy(),i)
    print(f'{df.columns[i]} = {vif}')
# Out:
# Cement (kg in a m^3 mixture) = 26.20971986418276
# Blast Furnace Slag (kg in a m^3 mixture) = 4.317258227374037
# Fly Ash (kg in a m^3 mixture) = 4.522806572372463
# Water (kg in a m^3 mixture) = 93.81842472780006
# Superplasticizer (kg in a m^3 mixture) = 5.499238992665309
# Coarse Aggregate  (kg in a m^3 mixture) = 88.73744860700927
# Fine Aggregate (kg in a m^3 mixture) = 73.17963361435146
# Age (day) = 2.461498093652631

# %% [markdown]
# # 5. Model Training

# %%
x = df.drop('Concrete compressive strength(MPa) ', axis=1)
y = df['Concrete compressive strength(MPa) ']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, train_size=.8, random_state=5)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 8), (200, 8), (800,), (200,))

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
def model_eval(model,input_data,output):
    score = model.score(input_data,output)
    print(score)

# %%
model_eval(model,x_train,y_train)
# Out:
# 0.6274391578090419

# %%
model_eval(model,x_test,y_test)
# Out:
# 0.5654376166188344
