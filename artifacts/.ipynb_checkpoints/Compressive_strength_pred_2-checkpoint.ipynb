# %% [markdown]
# # 1.Problem statement

# %% [raw]
# Predicting Compressive Strength of Concrete

# %%
# Import Libraries 
import numpy as np
import pandas as pd

import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

from scipy.stats import zscore

from sklearn.impute import KNNImputer

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score,accuracy_score

# %% [markdown]
# # 2. Data gathering

# %%
df = pd.read_csv(r"C:\Vijay\Project\Compressive strength predection\data\Concrete_Data.csv")

# %%
df
# Out:
#      Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0     540.0                 0.0      0.0  162.0               2.5
# 1     540.0                 0.0      0.0  162.0               2.5
# 2     332.5               142.5      0.0  228.0               0.0
# 3     332.5               142.5      0.0  228.0               0.0
# 4     198.6               132.4      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 995   158.6               148.9    116.0  175.1              15.0
# 996   152.6               238.7      0.0  200.0               6.3
# 997   310.0               142.8      0.0  167.9              10.0
# 998   304.8                 0.0     99.6  196.0               9.8
# 999   150.9                 0.0    183.9  166.6              11.6
#
#      Coarse_Aggregate  Fine_Aggregate  Age  Concrete_Compressive_Strength
# 0              1040.0           676.0   28                          79.99
# 1              1055.0           676.0   28                          61.89
# 2               932.0           594.0  270                          40.27
# 3               932.0           594.0  365                          41.05
# 4               978.4           825.5  360                          44.30
# ..                ...             ...  ...                            ...
# 995             953.3           719.7   28                          27.68
# 996            1001.8           683.9   28                          26.86
# 997             914.3           804.0   28                          45.30
# 998             959.4           705.2   28                          30.12
# 999             991.2           772.2   28                          15.57
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 3. EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1000 non-null   float64
#  1   Blast_Furnace_Slag             1000 non-null   float64
#  2   Fly_Ash                        1000 non-null   float64
#  3   Water                          1000 non-null   float64
#  4   Superplasticizer               1000 non-null   float64
#  5   Coarse_Aggregate               1000 non-null   float64
#  6   Fine_Aggregate                 1000 non-null   float64
#  7   Age                            1000 non-null   int64
#  8   Concrete_Compressive_Strength  1000 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 70.4 KB

# %%
df.isna().sum()
# Out:
# Cement                           0
# Blast_Furnace_Slag               0
# Fly_Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse_Aggregate                 0
# Fine_Aggregate                   0
# Age                              0
# Concrete_Compressive_Strength    0
# dtype: int64

# %% [raw]
# # Assumption
# 1. Linearity

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                  Cement  Blast_Furnace_Slag   Fly_Ash  \
# Cement                         1.000000           -0.268367 -0.399852
# Blast_Furnace_Slag            -0.268367            1.000000 -0.324537
# Fly_Ash                       -0.399852           -0.324537  1.000000
# Water                         -0.080754            0.108738 -0.272959
# Superplasticizer               0.100427            0.038641  0.378577
# Coarse_Aggregate              -0.117377           -0.287605  0.013752
# Fine_Aggregate                -0.229847           -0.280572  0.082990
# Age                            0.080175           -0.041152 -0.153180
# Concrete_Compressive_Strength  0.500086            0.128026 -0.101424
#
#                                   Water  Superplasticizer  Coarse_Aggregate  \
# Cement                        -0.080754          0.100427         -0.117377
# Blast_Furnace_Slag             0.108738          0.038641         -0.287605
# Fly_Ash                       -0.272959          0.378577          0.013752
# Water                          1.000000         -0.668030         -0.171723
# Superplasticizer              -0.668030          1.000000         -0.262132
# Coarse_Aggregate              -0.171723         -0.262132          1.000000
# Fine_Aggregate                -0.450713          0.226201         -0.184087
# Age                            0.282923         -0.190124         -0.012659
# Concrete_Compressive_Strength -0.295044          0.370697         -0.159582
#
#                                Fine_Aggregate       Age  \
# Cement                              -0.229847  0.080175
# Blast_Furnace_Slag                  -0.280572 -0.041152
# Fly_Ash                              0.082990 -0.153180
# Water                               -0.450713  0.282923
# Superplasticizer                     0.226201 -0.190124
# Coarse_Aggregate                    -0.184087 -0.012659
# Fine_Aggregate                       1.000000 -0.158490
# Age                                 -0.158490  1.000000
# Concrete_Compressive_Strength       -0.166763  0.333786
#
#                                Concrete_Compressive_Strength
# Cement                                              0.500086
# Blast_Furnace_Slag                                  0.128026
# Fly_Ash                                            -0.101424
# Water                                              -0.295044
# Superplasticizer                                    0.370697
# Coarse_Aggregate                                   -0.159582
# Fine_Aggregate                                     -0.166763
# Age                                                 0.333786
# Concrete_Compressive_Strength                       1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
df[['Cement']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df[['Blast_Furnace_Slag']].boxplot()
# Out:
# <AxesSubplot: >

# %%
def outlier(array): 
    z_score = zscore(array) 
    index_list = np.where(np.abs(z_score) > 3) 
    outliers = array[index_list] 
    return index_list,outliers[0]
outlier(df['Blast_Furnace_Slag'].to_numpy())
# Out:
# ((array([553, 559, 571, 584], dtype=int64),), 359.4)

# %%
df.iloc[[553,559,571,584],1]
# Out:
# 553    359.4
# 559    359.4
# 571    342.1
# 584    342.1
# Name: Blast_Furnace_Slag, dtype: float64

# %%
sns.kdeplot(df['Blast_Furnace_Slag'])
# Out:
# <AxesSubplot: xlabel='Blast_Furnace_Slag', ylabel='Density'>

# %%
df['Blast_Furnace_Slag'].median()
# Out:
# 20.0

# %%
df.iloc[[553,559,571,584],1]=df['Blast_Furnace_Slag'].median()

# %%
df.loc[[553,559,571,584]]
# Out:
#      Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 553   239.6                20.0      0.0  185.7               0.0
# 559   239.6                20.0      0.0  185.7               0.0
# 571   228.0                20.0      0.0  185.7               0.0
# 584   228.0                20.0      0.0  185.7               0.0
#
#      Coarse_Aggregate  Fine_Aggregate  Age  Concrete_Compressive_Strength
# 553             941.6           664.3    7                          25.42
# 559             941.6           664.3   28                          39.44
# 571             955.8           674.3   28                          39.70
# 584             955.8           674.3    7                          21.92

# %%
df[['Blast_Furnace_Slag']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df[['Fly_Ash']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df[['Water']].boxplot()
# Out:
# <AxesSubplot: >

# %%
outlier(df['Water'].to_numpy())
# Out:
# ((array([873, 936], dtype=int64),), 247.0)

# %%
df[['Superplasticizer']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df[['Coarse_Aggregate']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df[['Fine_Aggregate']].boxplot()
# Out:
# <AxesSubplot: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1000 non-null   float64
#  1   Blast_Furnace_Slag             1000 non-null   float64
#  2   Fly_Ash                        1000 non-null   float64
#  3   Water                          1000 non-null   float64
#  4   Superplasticizer               1000 non-null   float64
#  5   Coarse_Aggregate               1000 non-null   float64
#  6   Fine_Aggregate                 1000 non-null   float64
#  7   Age                            1000 non-null   int64
#  8   Concrete_Compressive_Strength  1000 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 70.4 KB

# %%
# No Multicolinearity
vif_list = []
for i in range(df.shape[1]-1):
    vif = variance_inflation_factor(df.to_numpy(),i)
    print(f'{df.columns[i]} = {vif}')
# Out:
# Cement = 26.284623122171123
# Blast_Furnace_Slag = 4.349479646687365
# Fly_Ash = 4.535525374601922
# Water = 94.255116353211
# Superplasticizer = 5.6008668155216075
# Coarse_Aggregate = 88.691364119811
# Fine_Aggregate = 72.93122488906465
# Age = 2.437877619604014

# %% [markdown]
# # 5. Model Training

# %%
x = df.drop('Concrete_Compressive_Strength', axis=1)
y = df['Concrete_Compressive_Strength']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, train_size=.8, random_state=6)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 8), (200, 8), (800,), (200,))

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
def model_eval(model,input_data,output):
    score = model.score(input_data,output)
    print(score)

# %%
model_eval(model,x_train,y_train)
# Out:
# 0.6056727808322939

# %%
model_eval(model,x_test,y_test)
# Out:
# 0.6374123555217277

# %% [markdown]
# ### user function

# %%
df.columns
# Out:
# Index(['Cement', 'Blast_Furnace_Slag', 'Fly_Ash', 'Water', 'Superplasticizer',
#        'Coarse_Aggregate', 'Fine_Aggregate', 'Age',
#        'Concrete_Compressive_Strength'],
#       dtype='object')

# %%
Cement = float(input('Cement : '))
Blast_Furnace_Slag = float(input('Blast_Furnace_Slag : '))
Fly_Ash = float(input('Fly_Ash : '))
Water = float(input('Water : '))
Superplasticizer = float(input('Superplasticizer : '))
Coarse_Aggregate = float(input('Coarse_Aggregate : '))
Fine_Aggregate = float(input('Fine_Aggregate : '))
Age = float(input('Age : '))
                      
data = np.array([Cement, Blast_Furnace_Slag, Fly_Ash, Water, Superplasticizer,
                 Coarse_Aggregate, Fine_Aggregate, Age], ndmin=2)

Concrete_Compressive_Strength = model.predict(data)[0]
print(Concrete_Compressive_Strength)
# Out:
# Cement : 300
# Blast_Furnace_Slag : 25
# Fly_Ash : 25
# Water : 200
# Superplasticizer : 30
# Coarse_Aggregate : 1000
# Fine_Aggregate : 900
# Age : 7
# 27.11226145594093
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
with open('model.pkl','wb') as file:
    pickle.dump(model,file)

# %%
# with open(r'C:\Vijay\Daily Notes\23_03_01_git\project\artifacts\model.pkl','rb') as file:
#     pickle.load(file)

# %%
def get_Compressive_Strength_Predction():
    """
    Compressive Strength Predction
    """

    Cement = 300  
    Blast_Furnace_Slag = 25 
    Fly_Ash = 25  
    Water = 200 
    Superplasticizer = 30  
    Coarse_Aggregate = 1000 
    Fine_Aggregate = 950
    Age = 28 


    user_data = np.zeros(len(df.columns)-1)
    user_data[0] = Cement
    user_data[1] = Blast_Furnace_Slag
    user_data[2] = Fly_Ash
    user_data[3] = Water
    user_data[4] = Superplasticizer
    user_data[5] = Coarse_Aggregate
    user_data[6] = Fine_Aggregate
    user_data[7] = Age
    

    return model.predict([user_data])[0]

# %%
get_Compressive_Strength_Predction()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 29.504490960439
